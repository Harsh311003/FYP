# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv('.\chronic_kidney_disease.csv')

# %% [markdown]
# # Analyzing the data

# %%
df.head()
# Out:
#   age  bp     sg al su  rbc  pc  pcc  ba  bgr  ... pcv  wbcc rbcc htn dm  cad  \
# 0  48  80   1.02  1  0    0   0    1   1  121  ...  44  7800  5.2   0  0    1
# 1   7  50   1.02  4  0    0   0    1   1    ?  ...  38  6000  0.0   1  1    1
# 2  62  80   1.01  2  3    0   0    1   1  423  ...  31  7500  0.0   1  0    1
# 3  48  70  1.005  4  0    0   1    0   1  117  ...  32  6700  3.9   0  1    1
# 4  51  80   1.01  2  0    0   0    1   1  106  ...  35  7300  4.6   1  1    1
#
#    appet  pe  ane  class
# 0      1   1    1    ckd
# 1      1   1    1    ckd
# 2      0   1    0    ckd
# 3      0   0    0    ckd
# 4      1   1    1    ckd
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     400 non-null    object
#  1   bp      400 non-null    object
#  2   sg      400 non-null    object
#  3   al      400 non-null    object
#  4   su      400 non-null    object
#  5   rbc     400 non-null    int64
#  6   pc      400 non-null    int64
#  7   pcc     400 non-null    int64
#  8   ba      400 non-null    int64
#  9   bgr     400 non-null    object
#  10  bu      400 non-null    object
#  11  sc      400 non-null    object
#  12  sod     400 non-null    object
#  13  pot     400 non-null    object
#  14  hemo    400 non-null    object
#  15  pcv     400 non-null    int64
#  16  wbcc    400 non-null    int64
#  17  rbcc    400 non-null    float64
#  18  htn     400 non-null    int64
#  19  dm      400 non-null    int64
#  20  cad     400 non-null    int64
#  21  appet   400 non-null    int64
#  22  pe      400 non-null    int64
#  23  ane     400 non-null    int64
#  24  class   400 non-null    object
# dtypes: float64(1), int64(12), object(12)
# memory usage: 78.2+ KB

# %% [markdown]
# # Database loading and pre-processing

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

#Create function for checking missing values which accepts a dataframe as its parameter
def null_values_check(df): 
    #Error handling to prevent abnormal termination of operation
    try:
        #if-else statement for null value check 
        if(df.isnull().values.any() == True):
            #if there are null values present, print a column-wise summary of records with null values
            print('Number of null records within each column:\n' + str(df.isnull().sum()))
        else:
            print('There is no missing values in the dataset.')
    
    except Exception as e:
        logging.error(e)

#initialise variable with dataset name
dataset_name = '.\chronic_kidney_disease.csv'

#error-handling to prevent abnormal termination of code
try:
    #import and load weather dataset into pandas dataframe
    chronic_kidney_disease_dataframe = pd.read_csv(dataset_name)
    
    #Description of Datasets
    #Print number of records and attributes of whole kidney dataset
    print('Shape of dataset: ' + str(chronic_kidney_disease_dataframe.shape))
    print('Total number of records in dataset = ' + str(chronic_kidney_disease_dataframe.shape[0]))
    print('Total number of attributes in dataset = ' + str(chronic_kidney_disease_dataframe.shape[1]))
    print('')
    #call function created to check for null values
    null_values_check(chronic_kidney_disease_dataframe)
    #Missing value imputation
    #replace ? to nan values 
    chronic_kidney_disease_dataframe = chronic_kidney_disease_dataframe.replace('?', np.nan)
    
    
    #set the features and the target variables
    target_class = chronic_kidney_disease_dataframe['class']
    print('\nAre there missing values in Target Class? ' + str(target_class.isna().any()))
    feature_classes = chronic_kidney_disease_dataframe.iloc[:, 0:24]
    print('\nAre there missing values in the Features? \n' + str(feature_classes.isna().any()))
    
    # replacing the null values
    #KNN imputation (n_neighbour = 5 means that the missing values will be replaced by the mean value of 5 nearest neighbors)
    knn_missing_values_imputer = KNNImputer(n_neighbors=5)
    feature_classes = pd.DataFrame(knn_missing_values_imputer.fit_transform(feature_classes),
                                   columns = feature_classes.columns)
    print('\nNow, Are there any missing values in Features? ' + str(feature_classes.isna().any()))
    
    
    #Scaling and normalization of features
    standard_feature_scaler = StandardScaler()
    feature_classes = standard_feature_scaler.fit_transform(feature_classes)
    feature_classes = pd.DataFrame(feature_classes, columns=['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 
                                                             'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 
                                                             'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 
                                                             'cad', 'appet', 'pe', 'ane'])
    
    #Encoding target class using label encoding
    target_label_encoder = preprocessing.LabelEncoder()
    target_class = target_label_encoder.fit_transform(target_class)
    
    X=feature_classes
    y=target_class
    
    #split the dataset into training and testing data using K Fold Approach
    kf = StratifiedKFold(n_splits=5, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
        
    print('\nAfter Pre-processing:')
    print('Size of train dataset: ' + str(X_train.shape[0]))
    print('Size of test dataset: ' + str(y_test.shape[0]))
                                                      
except FileNotFoundError as e:
    logging.error(e)
# Out:
# Shape of dataset: (400, 25)
# Total number of records in dataset = 400
# Total number of attributes in dataset = 25
#
# There is no missing values in the dataset.
#
# Are there missing values in Target Class? False
#
# Are there missing values in the Features?
# age       True
# bp        True
# sg        True
# al        True
# su        True
# rbc      False
# pc       False
# pcc      False
# ba       False
# bgr       True
# bu        True
# sc        True
# sod       True
# pot       True
# hemo      True
# pcv      False
# wbcc     False
# rbcc     False
# htn      False
# dm       False
# cad      False
# appet    False
# pe       False
# ane      False
# dtype: bool
#
# Now, Are there any missing values in Features? age      False
# bp       False
# sg       False
# al       False
# su       False
# rbc      False
# pc       False
# pcc      False
# ba       False
# bgr      False
# bu       False
# sc       False
# sod      False
# pot      False
# hemo     False
# pcv      False
# wbcc     False
# rbcc     False
# htn      False
# dm       False
# cad      False
# appet    False
# pe       False
# ane      False
# dtype: bool
#
# After Pre-processing:
# Size of train dataset: 320
# Size of test dataset: 80

# %% [markdown]
# # Converting each column to float data type

# %%
# taking the length of the column and converting the each column to float
colLength = (len(chronic_kidney_disease_dataframe.axes[1]))

# for storing the position of each column
count=0;

for i in chronic_kidney_disease_dataframe:
    count += 1
    # the last column of the data set is label so when we reach last column just break the loop
    if(count==25):
        break
    
    # converting each column to float data type
    
    chronic_kidney_disease_dataframe[i] = chronic_kidney_disease_dataframe[i].astype('float64')

# %%
chronic_kidney_disease_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     391 non-null    float64
#  1   bp      388 non-null    float64
#  2   sg      353 non-null    float64
#  3   al      354 non-null    float64
#  4   su      351 non-null    float64
#  5   rbc     400 non-null    float64
#  6   pc      400 non-null    float64
#  7   pcc     400 non-null    float64
#  8   ba      400 non-null    float64
#  9   bgr     356 non-null    float64
#  10  bu      381 non-null    float64
#  11  sc      383 non-null    float64
#  12  sod     313 non-null    float64
#  13  pot     312 non-null    float64
#  14  hemo    348 non-null    float64
#  15  pcv     400 non-null    float64
#  16  wbcc    400 non-null    float64
#  17  rbcc    400 non-null    float64
#  18  htn     400 non-null    float64
#  19  dm      400 non-null    float64
#  20  cad     400 non-null    float64
#  21  appet   400 non-null    float64
#  22  pe      400 non-null    float64
#  23  ane     400 non-null    float64
#  24  class   400 non-null    object
# dtypes: float64(24), object(1)
# memory usage: 78.2+ KB

# %%
chronic_kidney_disease_dataframe['class'].value_counts()
chronic_kidney_disease_dataframe['class'] = chronic_kidney_disease_dataframe['class'].replace(to_replace={'ckd\t':'ckd'})
chronic_kidney_disease_dataframe["class"] = [1 if i == "ckd" else 0 for i in chronic_kidney_disease_dataframe["class"]]
features = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
           'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
           'appet', 'pe', 'ane']

# %% [markdown]
# # Filling empty cell or null values with median

# %%
for feature in features:
    chronic_kidney_disease_dataframe[feature] = chronic_kidney_disease_dataframe[feature].fillna(chronic_kidney_disease_dataframe[feature].median())

# %% [markdown]
# # Checking For Null Values

# %%
chronic_kidney_disease_dataframe.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# # Fisher Score

# %%
from skfeature.function.similarity_based import fisher_score
# %matplotlib inline

# Calculating Score
scores = fisher_score.fisher_score(np.array(X_train),np.array(y_train))
scores
# Out:
# array([ 9, 21,  6, 20,  8,  5,  4,  2, 14, 13, 17,  1, 11, 19,  0, 18, 12,
#        22, 23, 16,  3,  7, 15, 10])

# %%
# converting to pandas series
fisher_score = pd.Series(scores,index=X_train.columns)
fisher_score
# Out:
# age       9
# bp       21
# sg        6
# al       20
# su        8
# rbc       5
# pc        4
# pcc       2
# ba       14
# bgr      13
# bu       17
# sc        1
# sod      11
# pot      19
# hemo      0
# pcv      18
# wbcc     12
# rbcc     22
# htn      23
# dm       16
# cad       3
# appet     7
# pe       15
# ane      10
# dtype: int32

# %%
# Displaying the Fisher Score in Descending order
fisher_score.sort_values(ascending=False)
# Out:
# htn      23
# rbcc     22
# bp       21
# al       20
# pot      19
# pcv      18
# bu       17
# dm       16
# pe       15
# ba       14
# bgr      13
# wbcc     12
# sod      11
# ane      10
# age       9
# su        8
# appet     7
# sg        6
# rbc       5
# pc        4
# cad       3
# pcc       2
# sc        1
# hemo      0
# dtype: int32

# %%
# Sorting in Descending order & Ploting 
fisher_score.sort_values(ascending=False).plot.bar(xlabel="Features",ylabel="Fisher score",figsize=(20, 8))
# Out:
# <AxesSubplot: xlabel='Features', ylabel='Fisher score'>

# %%
# Independent and Dependent Feature:
X = chronic_kidney_disease_dataframe.iloc[:, :-1]
y = chronic_kidney_disease_dataframe.iloc[:, -1]

# %% [markdown]
# # Function for calling different classifier and splitting of dataset into traning and testing and selecting the best feature from the Fisher Score

# %%
# selecting the top feature
from sklearn.feature_selection import SelectKBest
def selectFeature(n):
    return fisher_score.nlargest(n).index

# for selecting all the details of the dataset based on the selected top feature
# chronic_kidney_disease_dataframe[['sg', 'htn', 'hemo', 'dm', 'al', 'appet', 'rc', 'pc']]
dataset=[]
def topFeature(feature):
    dataset=[]
    topFeature = []
    for i in feature:
        topFeature.append(i)
    dataset.append(topFeature)
    return dataset

# the classifier function

# calling classifier
def classifierUsed(selectedDataSetForTraining,feature,number):
    
    randomForestClassifier(selectedDataSetForTraining,feature,number)
    decisionTreeClassifier(selectedDataSetForTraining,feature,number)
    KNNClassifier(selectedDataSetForTraining,feature,number)
    logisticRegressionClassifier(selectedDataSetForTraining,feature,number)
    supportVectorMachineClassifier(selectedDataSetForTraining,feature,number)
    
    
# function for random forest classifiers
def numberOfFeatureForClassifier(number):
    selectedFeature = selectFeature(number)
    feature =[]
    for i in selectedFeature:
        # appending the selected feature into a list
        feature.append(i)

    selectedDataSetForTraining = topFeature(feature)
    
    # calling the classifier function
    classifierUsed(selectedDataSetForTraining,feature,number)
    
n_Featurelist = []            # To store no of features

# Format: list = [[Accuracy scores],[Percision scores],[F1 scores],[Recall scores]]

rf_list = [[],[],[],[]]       # To store rf performance
dt_list = [[],[],[],[]]       # To store dt performance
lr_list = [[],[],[],[]]       # To store lr performance
knn_list = [[],[],[],[]]      # To store knn performance
svm_list = [[],[],[],[]]      # To store svm performance

# %% [markdown]
#  # Random Forest Classifier

# %%
# Random Forest classifier function
from sklearn.ensemble import RandomForestClassifier

def randomForestClassifier(selectedDataSetForTraining,feature,number):
    
    # printing the top feature
    print("Using Random Forest Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5  
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]

    
    # RandomForestClassifier:
    RandomForest = RandomForestClassifier()
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=RandomForest,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending no of features to Feature list 
    n_Featurelist.append(str(number))
    
    # Appending avg accuracy to list 
    rf_list[0].append(avg_Accuracy)
    
    print('Accuracy list {} & No of Feature list {}'.format(rf_list[0],n_Featurelist))
    
    RandomForest = RandomForest.fit(X_train,y_train)
    
    # Predictions:
    y_pred=RandomForest.predict(X_test)

    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    rf_list[1].append(precision_score)
    print('Precision list',rf_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    rf_list[2].append(f1_score)
    print('F1-score list',rf_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    rf_list[3].append(recall_score)
    print('Recall list',rf_list[3])
    
    print()
    
    print('\nClassification Report:\n',metrics.classification_report(y_test,y_pred))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Decision Tree Classifier

# %%
# Decision Tree Classifier:
from sklearn.tree import DecisionTreeClassifier

def decisionTreeClassifier(selectedDataSetForTraining,feature,number):

     # printing the top feature
    print("Using Decision Tree Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    
    # Decision Tree Classifier:
    decision_tree_model = DecisionTreeClassifier(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=decision_tree_model,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending avg accuracy to list
    dt_list[0].append(avg_Accuracy)
    print('Accuracy list',(dt_list[0]))
    
    decision_tree_model = decision_tree_model.fit(X_train,y_train)

    #DT predictions on test features
    y_pred = decision_tree_model.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to listv
    dt_list[1].append(precision_score)
    print('Precision list',dt_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    dt_list[2].append(f1_score)
    print('F1-score list',dt_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    dt_list[3].append(recall_score)
    print('Recall list',dt_list[3])
    
    print()
    
     #display classification report for Decision Tree
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))

    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # KNN Classifier

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

def KNNClassifier(selectedDataSetForTraining,feature,number):

    print("Using KNN Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    #KNN Classifier:
    KNN_classifier = KNeighborsClassifier(n_neighbors=5)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=KNN_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending avg accuracy to list
    knn_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(knn_list[0]))
    
    KNN_classifier = KNN_classifier.fit(X_train,y_train)

    #KNN predictions on test features
    y_pred = KNN_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    knn_list[1].append(precision_score)
    print('Precision list',knn_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    knn_list[2].append(f1_score)
    print('F1-score list',knn_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    knn_list[3].append(recall_score)
    print('Recall list',knn_list[3])
    
    print()
    
     #display classification report for KNN
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))

    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Logistic Regression Classifier

# %%
#Logistic Regression Classification
from sklearn.linear_model import LogisticRegression 

def logisticRegressionClassifier(selectedDataSetForTraining,feature,number):

    # printing the top feature
    print("Using Logistic Regression Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
        
    #Logistic Regression Classifier:    
    LR_classifier = LogisticRegression(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=LR_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)

    # Appending avg accuracy to list
    lr_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(lr_list[0]))
    
    LR_classifier.fit(X_train,y_train)

    #LR predictions on test features
    y_pred = LR_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    lr_list[1].append(precision_score)
    print('Precision list',lr_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    lr_list[2].append(f1_score)
    print('F1-score list',lr_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    lr_list[3].append(recall_score)
    print('Recall list',lr_list[3])
    print()
    
    #display classification report for LR
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Support Vector Machine Classifier

# %%
#Support vector machine
from sklearn.svm import SVC

def supportVectorMachineClassifier(selectedDataSetForTraining,feature,number):
    
    # printing the top feature
    print("Using Support vector machine Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()

    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    # Support Vector Machine Classifier :
    
    SVM_classifier = support_vector_machine_model = SVC(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=SVM_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)

    # Appending avg accuracy to list
    svm_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(svm_list[0]))
    
    SVM_classifier.fit(X_train,y_train)

    #svm predictions on test features
    y_pred = SVM_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    svm_list[1].append(precision_score)
    print('Precision list',svm_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    svm_list[2].append(f1_score)
    print('F1-score list',svm_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    svm_list[3].append(recall_score)
    print('Recall list',svm_list[3])
    
    print()
    
     #display classification report for SVM 
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # CALLING THE MODEL

# %% [markdown]
# ## No of features used: 4

# %%
numberOfFeatureForClassifier(4)
# Out:
# Using Random Forest Classification
# The top 4 features are:
# ['htn', 'rbcc', 'bp', 'al']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.921875 0.953125 0.921875]
# Accuracy with k fold validation 93.75
# Accuracy list [93.75] & No of Feature list ['4']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68]
#
# Recall:
#  99.0
# Recall list [99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 4 features are:
# ['htn', 'rbcc', 'bp', 'al']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.921875 0.96875  0.90625 ]
# Accuracy with k fold validation 93.75
# Accuracy list [93.75]
#
# Confusion matrix:
#  [[30  0]
#  [ 2 48]]
#
#
# Precision :
#  96.88
# Precision list [96.88]
#
# F1-score:
#  97.37
# F1-score list [97.37]
#
# Recall:
#  98.0
# Recall list [98.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        30
#            1       1.00      0.96      0.98        50
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 4 features are:
# ['htn', 'rbcc', 'bp', 'al']
#
# Accuracy of 5 fold - [0.984375 0.890625 0.890625 0.953125 0.953125]
# Accuracy with k fold validation 93.44
# Accuracy list [93.44]
#
# Confusion matrix:
#  [[30  0]
#  [ 2 48]]
#
#
# Precision :
#  96.88
# Precision list [96.88]
#
# F1-score:
#  97.37
# F1-score list [97.37]
#
# Recall:
#  98.0
# Recall list [98.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        30
#            1       1.00      0.96      0.98        50
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 4 features are:
# ['htn', 'rbcc', 'bp', 'al']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.875    0.96875  0.953125]
# Accuracy with k fold validation 93.75
# Accuracy list [93.75]
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68]
#
# Recall:
#  99.0
# Recall list [99.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 4 features are:
# ['htn', 'rbcc', 'bp', 'al']
#
# Accuracy of 5 fold - [0.609375 0.625    0.625    0.625    0.65625 ]
# Accuracy with k fold validation 62.81
# Accuracy list [62.81]
#
# Confusion matrix:
#  [[10 20]
#  [ 0 50]]
#
#
# Precision :
#  85.71
# Precision list [85.71]
#
# F1-score:
#  66.67
# F1-score list [66.67]
#
# Recall:
#  66.67
# Recall list [66.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        30
#            1       0.71      1.00      0.83        50
#
#     accuracy                           0.75        80
#    macro avg       0.86      0.67      0.67        80
# weighted avg       0.82      0.75      0.71        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 5

# %%
numberOfFeatureForClassifier(5)
# Out:
# Using Random Forest Classification
# The top 5 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.90625  0.9375   0.9375  ]
# Accuracy with k fold validation 93.44
# Accuracy list [93.75, 93.44] & No of Feature list ['4', '5']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 5 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot']
#
# Accuracy of 5 fold - [0.953125 0.875    0.859375 0.890625 0.90625 ]
# Accuracy with k fold validation 89.69
# Accuracy list [93.75, 89.69]
#
# Confusion matrix:
#  [[30  0]
#  [ 3 47]]
#
#
# Precision :
#  95.45
# Precision list [96.88, 95.45]
#
# F1-score:
#  96.07
# F1-score list [97.37, 96.07]
#
# Recall:
#  97.0
# Recall list [98.0, 97.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        30
#            1       1.00      0.94      0.97        50
#
#     accuracy                           0.96        80
#    macro avg       0.95      0.97      0.96        80
# weighted avg       0.97      0.96      0.96        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 5 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot']
#
# Accuracy of 5 fold - [0.953125 0.890625 0.890625 0.953125 0.921875]
# Accuracy with k fold validation 92.19000000000001
# Accuracy list [93.44, 92.19000000000001]
#
# Confusion matrix:
#  [[30  0]
#  [ 3 47]]
#
#
# Precision :
#  95.45
# Precision list [96.88, 95.45]
#
# F1-score:
#  96.07
# F1-score list [97.37, 96.07]
#
# Recall:
#  97.0
# Recall list [98.0, 97.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        30
#            1       1.00      0.94      0.97        50
#
#     accuracy                           0.96        80
#    macro avg       0.95      0.97      0.96        80
# weighted avg       0.97      0.96      0.96        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 5 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.875    0.96875  0.96875 ]
# Accuracy with k fold validation 94.06
# Accuracy list [93.75, 94.06]
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 5 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot']
#
# Accuracy of 5 fold - [0.609375 0.625    0.625    0.625    0.625   ]
# Accuracy with k fold validation 62.19
# Accuracy list [62.81, 62.19]
#
# Confusion matrix:
#  [[ 9 21]
#  [ 0 50]]
#
#
# Precision :
#  85.21
# Precision list [85.71, 85.21]
#
# F1-score:
#  64.4
# F1-score list [66.67, 64.4]
#
# Recall:
#  65.0
# Recall list [66.67, 65.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.30      0.46        30
#            1       0.70      1.00      0.83        50
#
#     accuracy                           0.74        80
#    macro avg       0.85      0.65      0.64        80
# weighted avg       0.82      0.74      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 6

# %%
numberOfFeatureForClassifier(6)
# Out:
# Using Random Forest Classification
# The top 6 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv']
#
# Accuracy of 5 fold - [0.984375 0.9375   0.9375   0.96875  0.953125]
# Accuracy with k fold validation 95.62
# Accuracy list [93.75, 93.44, 95.62] & No of Feature list ['4', '5', '6']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 6 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv']
#
# Accuracy of 5 fold - [0.96875  0.921875 0.90625  0.921875 0.921875]
# Accuracy with k fold validation 92.81
# Accuracy list [93.75, 89.69, 92.81]
#
# Confusion matrix:
#  [[30  0]
#  [ 3 47]]
#
#
# Precision :
#  95.45
# Precision list [96.88, 95.45, 95.45]
#
# F1-score:
#  96.07
# F1-score list [97.37, 96.07, 96.07]
#
# Recall:
#  97.0
# Recall list [98.0, 97.0, 97.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        30
#            1       1.00      0.94      0.97        50
#
#     accuracy                           0.96        80
#    macro avg       0.95      0.97      0.96        80
# weighted avg       0.97      0.96      0.96        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 6 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv']
#
# Accuracy of 5 fold - [0.953125 0.890625 0.921875 0.9375   0.953125]
# Accuracy with k fold validation 93.12
# Accuracy list [93.44, 92.19000000000001, 93.12]
#
# Confusion matrix:
#  [[30  0]
#  [ 4 46]]
#
#
# Precision :
#  94.12
# Precision list [96.88, 95.45, 94.12]
#
# F1-score:
#  94.78999999999999
# F1-score list [97.37, 96.07, 94.78999999999999]
#
# Recall:
#  96.0
# Recall list [98.0, 97.0, 96.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        30
#            1       1.00      0.92      0.96        50
#
#     accuracy                           0.95        80
#    macro avg       0.94      0.96      0.95        80
# weighted avg       0.96      0.95      0.95        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 6 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv']
#
# Accuracy of 5 fold - [0.984375 0.921875 0.859375 0.953125 0.953125]
# Accuracy with k fold validation 93.44
# Accuracy list [93.75, 94.06, 93.44]
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 6 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv']
#
# Accuracy of 5 fold - [0.890625 0.9375   0.921875 0.9375   0.90625 ]
# Accuracy with k fold validation 91.88
# Accuracy list [62.81, 62.19, 91.88]
#
# Confusion matrix:
#  [[30  0]
#  [ 6 44]]
#
#
# Precision :
#  91.67
# Precision list [85.71, 85.21, 91.67]
#
# F1-score:
#  92.25999999999999
# F1-score list [66.67, 64.4, 92.25999999999999]
#
# Recall:
#  94.0
# Recall list [66.67, 65.0, 94.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        30
#            1       1.00      0.88      0.94        50
#
#     accuracy                           0.93        80
#    macro avg       0.92      0.94      0.92        80
# weighted avg       0.94      0.93      0.93        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 7

# %%
numberOfFeatureForClassifier(7)
# Out:
# Using Random Forest Classification
# The top 7 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu']
#
# Accuracy of 5 fold - [0.984375 0.953125 0.9375   0.96875  0.953125]
# Accuracy with k fold validation 95.94
# Accuracy list [93.75, 93.44, 95.62, 95.94] & No of Feature list ['4', '5', '6', '7']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0, 99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 7 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu']
#
# Accuracy of 5 fold - [0.921875 0.890625 0.9375   0.953125 0.953125]
# Accuracy with k fold validation 93.12
# Accuracy list [93.75, 89.69, 92.81, 93.12]
#
# Confusion matrix:
#  [[29  1]
#  [ 3 47]]
#
#
# Precision :
#  94.27
# Precision list [96.88, 95.45, 95.45, 94.27]
#
# F1-score:
#  94.73
# F1-score list [97.37, 96.07, 96.07, 94.73]
#
# Recall:
#  95.33
# Recall list [98.0, 97.0, 97.0, 95.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        30
#            1       0.98      0.94      0.96        50
#
#     accuracy                           0.95        80
#    macro avg       0.94      0.95      0.95        80
# weighted avg       0.95      0.95      0.95        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 7 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu']
#
# Accuracy of 5 fold - [0.890625 0.859375 0.890625 0.890625 0.90625 ]
# Accuracy with k fold validation 88.75
# Accuracy list [93.44, 92.19000000000001, 93.12, 88.75]
#
# Confusion matrix:
#  [[30  0]
#  [ 7 43]]
#
#
# Precision :
#  90.53999999999999
# Precision list [96.88, 95.45, 94.12, 90.53999999999999]
#
# F1-score:
#  91.01
# F1-score list [97.37, 96.07, 94.78999999999999, 91.01]
#
# Recall:
#  93.0
# Recall list [98.0, 97.0, 96.0, 93.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        30
#            1       1.00      0.86      0.92        50
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.93      0.91        80
# weighted avg       0.93      0.91      0.91        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 7 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu']
#
# Accuracy of 5 fold - [0.984375 0.921875 0.859375 0.953125 0.953125]
# Accuracy with k fold validation 93.44
# Accuracy list [93.75, 94.06, 93.44, 93.44]
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0, 99.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 7 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu']
#
# Accuracy of 5 fold - [0.90625  0.875    0.890625 0.890625 0.859375]
# Accuracy with k fold validation 88.44
# Accuracy list [62.81, 62.19, 91.88, 88.44]
#
# Confusion matrix:
#  [[30  0]
#  [ 7 43]]
#
#
# Precision :
#  90.53999999999999
# Precision list [85.71, 85.21, 91.67, 90.53999999999999]
#
# F1-score:
#  91.01
# F1-score list [66.67, 64.4, 92.25999999999999, 91.01]
#
# Recall:
#  93.0
# Recall list [66.67, 65.0, 94.0, 93.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        30
#            1       1.00      0.86      0.92        50
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.93      0.91        80
# weighted avg       0.93      0.91      0.91        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 9

# %%
numberOfFeatureForClassifier(9)
# Out:
# Using Random Forest Classification
# The top 9 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe']
#
# Accuracy of 5 fold - [0.984375 0.921875 0.9375   0.96875  0.96875 ]
# Accuracy with k fold validation 95.62
# Accuracy list [93.75, 93.44, 95.62, 95.94, 95.62] & No of Feature list ['4', '5', '6', '7', '9']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0, 99.0, 99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 9 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe']
#
# Accuracy of 5 fold - [0.9375   0.875    0.953125 0.953125 0.96875 ]
# Accuracy with k fold validation 93.75
# Accuracy list [93.75, 89.69, 92.81, 93.12, 93.75]
#
# Confusion matrix:
#  [[29  1]
#  [ 5 45]]
#
#
# Precision :
#  91.56
# Precision list [96.88, 95.45, 95.45, 94.27, 91.56]
#
# F1-score:
#  92.19000000000001
# F1-score list [97.37, 96.07, 96.07, 94.73, 92.19000000000001]
#
# Recall:
#  93.33
# Recall list [98.0, 97.0, 97.0, 95.33, 93.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91        30
#            1       0.98      0.90      0.94        50
#
#     accuracy                           0.93        80
#    macro avg       0.92      0.93      0.92        80
# weighted avg       0.93      0.93      0.93        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 9 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe']
#
# Accuracy of 5 fold - [0.890625 0.859375 0.890625 0.890625 0.90625 ]
# Accuracy with k fold validation 88.75
# Accuracy list [93.44, 92.19000000000001, 93.12, 88.75, 88.75]
#
# Confusion matrix:
#  [[30  0]
#  [ 7 43]]
#
#
# Precision :
#  90.53999999999999
# Precision list [96.88, 95.45, 94.12, 90.53999999999999, 90.53999999999999]
#
# F1-score:
#  91.01
# F1-score list [97.37, 96.07, 94.78999999999999, 91.01, 91.01]
#
# Recall:
#  93.0
# Recall list [98.0, 97.0, 96.0, 93.0, 93.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        30
#            1       1.00      0.86      0.92        50
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.93      0.91        80
# weighted avg       0.93      0.91      0.91        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 9 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.875    0.9375   0.96875 ]
# Accuracy with k fold validation 93.44
# Accuracy list [93.75, 94.06, 93.44, 93.44, 93.44]
#
# Confusion matrix:
#  [[30  0]
#  [ 2 48]]
#
#
# Precision :
#  96.88
# Precision list [98.39, 98.39, 98.39, 98.39, 96.88]
#
# F1-score:
#  97.37
# F1-score list [98.68, 98.68, 98.68, 98.68, 97.37]
#
# Recall:
#  98.0
# Recall list [99.0, 99.0, 99.0, 99.0, 98.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        30
#            1       1.00      0.96      0.98        50
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 9 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe']
#
# Accuracy of 5 fold - [0.90625  0.875    0.890625 0.875    0.84375 ]
# Accuracy with k fold validation 87.81
# Accuracy list [62.81, 62.19, 91.88, 88.44, 87.81]
#
# Confusion matrix:
#  [[30  0]
#  [ 7 43]]
#
#
# Precision :
#  90.53999999999999
# Precision list [85.71, 85.21, 91.67, 90.53999999999999, 90.53999999999999]
#
# F1-score:
#  91.01
# F1-score list [66.67, 64.4, 92.25999999999999, 91.01, 91.01]
#
# Recall:
#  93.0
# Recall list [66.67, 65.0, 94.0, 93.0, 93.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        30
#            1       1.00      0.86      0.92        50
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.93      0.91        80
# weighted avg       0.93      0.91      0.91        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 15

# %%
numberOfFeatureForClassifier(15)
# Out:
# Using Random Forest Classification
# The top 15 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age']
#
# Accuracy of 5 fold - [0.984375 0.9375   0.9375   0.96875  0.984375]
# Accuracy with k fold validation 96.25
# Accuracy list [93.75, 93.44, 95.62, 95.94, 95.62, 96.25] & No of Feature list ['4', '5', '6', '7', '9', '15']
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [98.39, 98.39, 98.39, 98.39, 98.39, 98.39]
#
# F1-score:
#  98.68
# F1-score list [98.68, 98.68, 98.68, 98.68, 98.68, 98.68]
#
# Recall:
#  99.0
# Recall list [99.0, 99.0, 99.0, 99.0, 99.0, 99.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 15 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age']
#
# Accuracy of 5 fold - [0.984375 0.90625  0.921875 0.921875 0.921875]
# Accuracy with k fold validation 93.12
# Accuracy list [93.75, 89.69, 92.81, 93.12, 93.75, 93.12]
#
# Confusion matrix:
#  [[30  0]
#  [ 3 47]]
#
#
# Precision :
#  95.45
# Precision list [96.88, 95.45, 95.45, 94.27, 91.56, 95.45]
#
# F1-score:
#  96.07
# F1-score list [97.37, 96.07, 96.07, 94.73, 92.19000000000001, 96.07]
#
# Recall:
#  97.0
# Recall list [98.0, 97.0, 97.0, 95.33, 93.33, 97.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        30
#            1       1.00      0.94      0.97        50
#
#     accuracy                           0.96        80
#    macro avg       0.95      0.97      0.96        80
# weighted avg       0.97      0.96      0.96        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 15 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age']
#
# Accuracy of 5 fold - [0.6875   0.703125 0.734375 0.765625 0.71875 ]
# Accuracy with k fold validation 72.19
# Accuracy list [93.44, 92.19000000000001, 93.12, 88.75, 88.75, 72.19]
#
# Confusion matrix:
#  [[27  3]
#  [19 31]]
#
#
# Precision :
#  74.94
# Precision list [96.88, 95.45, 94.12, 90.53999999999999, 90.53999999999999, 74.94]
#
# F1-score:
#  72.43
# F1-score list [97.37, 96.07, 94.78999999999999, 91.01, 91.01, 72.43]
#
# Recall:
#  76.0
# Recall list [98.0, 97.0, 96.0, 93.0, 93.0, 76.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.90      0.71        30
#            1       0.91      0.62      0.74        50
#
#     accuracy                           0.73        80
#    macro avg       0.75      0.76      0.72        80
# weighted avg       0.79      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 15 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age']
#
# Accuracy of 5 fold - [0.875    0.921875 0.921875 0.953125 0.953125]
# Accuracy with k fold validation 92.5
# Accuracy list [93.75, 94.06, 93.44, 93.44, 93.44, 92.5]
#
# Confusion matrix:
#  [[28  2]
#  [ 2 48]]
#
#
# Precision :
#  94.67
# Precision list [98.39, 98.39, 98.39, 98.39, 96.88, 94.67]
#
# F1-score:
#  94.67
# F1-score list [98.68, 98.68, 98.68, 98.68, 97.37, 94.67]
#
# Recall:
#  94.67
# Recall list [99.0, 99.0, 99.0, 99.0, 98.0, 94.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        30
#            1       0.96      0.96      0.96        50
#
#     accuracy                           0.95        80
#    macro avg       0.95      0.95      0.95        80
# weighted avg       0.95      0.95      0.95        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 15 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [62.81, 62.19, 91.88, 88.44, 87.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [23 27]]
#
#
# Precision :
#  74.0
# Precision list [85.71, 85.21, 91.67, 90.53999999999999, 90.53999999999999, 74.0]
#
# F1-score:
#  68.75
# F1-score list [66.67, 64.4, 92.25999999999999, 91.01, 91.01, 68.75]
#
# Recall:
#  73.67
# Recall list [66.67, 65.0, 94.0, 93.0, 93.0, 73.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69        30
#            1       0.93      0.54      0.68        50
#
#     accuracy                           0.69        80
#    macro avg       0.74      0.74      0.69        80
# weighted avg       0.79      0.69      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used: 18

# %%
numberOfFeatureForClassifier(18)
# Out:
# Using Random Forest Classification
# The top 18 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age', 'su', 'appet', 'sg']
#
# Accuracy of 5 fold - [0.984375 0.96875  0.96875  0.984375 0.984375]
# Accuracy with k fold validation 97.81
# Accuracy list [93.75, 93.44, 95.62, 95.94, 95.62, 96.25, 97.81] & No of Feature list ['4', '5', '6', '7', '9', '15', '18']
#
# Confusion matrix:
#  [[30  0]
#  [ 0 50]]
#
#
# Precision :
#  100.0
# Precision list [98.39, 98.39, 98.39, 98.39, 98.39, 98.39, 100.0]
#
# F1-score:
#  100.0
# F1-score list [98.68, 98.68, 98.68, 98.68, 98.68, 98.68, 100.0]
#
# Recall:
#  100.0
# Recall list [99.0, 99.0, 99.0, 99.0, 99.0, 99.0, 100.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
#
# ---------------------------------------------------------------------
#
# Using Decision Tree Classification
# The top 18 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age', 'su', 'appet', 'sg']
#
# Accuracy of 5 fold - [0.953125 0.984375 0.984375 0.921875 0.96875 ]
# Accuracy with k fold validation 96.25
# Accuracy list [93.75, 89.69, 92.81, 93.12, 93.75, 93.12, 96.25]
#
# Confusion matrix:
#  [[30  0]
#  [ 2 48]]
#
#
# Precision :
#  96.88
# Precision list [96.88, 95.45, 95.45, 94.27, 91.56, 95.45, 96.88]
#
# F1-score:
#  97.37
# F1-score list [97.37, 96.07, 96.07, 94.73, 92.19000000000001, 96.07, 97.37]
#
# Recall:
#  98.0
# Recall list [98.0, 97.0, 97.0, 95.33, 93.33, 97.0, 98.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        30
#            1       1.00      0.96      0.98        50
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80
#
# ---------------------------------------------------------------------
#
# Using KNN Classification
# The top 18 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age', 'su', 'appet', 'sg']
#
# Accuracy of 5 fold - [0.6875   0.703125 0.734375 0.765625 0.71875 ]
# Accuracy with k fold validation 72.19
# Accuracy list [93.44, 92.19000000000001, 93.12, 88.75, 88.75, 72.19, 72.19]
#
# Confusion matrix:
#  [[27  3]
#  [19 31]]
#
#
# Precision :
#  74.94
# Precision list [96.88, 95.45, 94.12, 90.53999999999999, 90.53999999999999, 74.94, 74.94]
#
# F1-score:
#  72.43
# F1-score list [97.37, 96.07, 94.78999999999999, 91.01, 91.01, 72.43, 72.43]
#
# Recall:
#  76.0
# Recall list [98.0, 97.0, 96.0, 93.0, 93.0, 76.0, 76.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.90      0.71        30
#            1       0.91      0.62      0.74        50
#
#     accuracy                           0.73        80
#    macro avg       0.75      0.76      0.72        80
# weighted avg       0.79      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
# Using Logistic Regression Classification
# The top 18 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age', 'su', 'appet', 'sg']
#
# Accuracy of 5 fold - [0.90625  0.921875 0.875    0.90625  0.953125]
# Accuracy with k fold validation 91.25
# Accuracy list [93.75, 94.06, 93.44, 93.44, 93.44, 92.5, 91.25]
#
# Confusion matrix:
#  [[28  2]
#  [ 3 47]]
#
#
# Precision :
#  93.12
# Precision list [98.39, 98.39, 98.39, 98.39, 96.88, 94.67, 93.12]
#
# F1-score:
#  93.38
# F1-score list [98.68, 98.68, 98.68, 98.68, 97.37, 94.67, 93.38]
#
# Recall:
#  93.67
# Recall list [99.0, 99.0, 99.0, 99.0, 98.0, 94.67, 93.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92        30
#            1       0.96      0.94      0.95        50
#
#     accuracy                           0.94        80
#    macro avg       0.93      0.94      0.93        80
# weighted avg       0.94      0.94      0.94        80
#
# ---------------------------------------------------------------------
#
# Using Support vector machine Classification
# The top 18 features are:
# ['htn', 'rbcc', 'bp', 'al', 'pot', 'pcv', 'bu', 'dm', 'pe', 'ba', 'bgr', 'wbcc', 'sod', 'ane', 'age', 'su', 'appet', 'sg']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [62.81, 62.19, 91.88, 88.44, 87.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [23 27]]
#
#
# Precision :
#  74.0
# Precision list [85.71, 85.21, 91.67, 90.53999999999999, 90.53999999999999, 74.0, 74.0]
#
# F1-score:
#  68.75
# F1-score list [66.67, 64.4, 92.25999999999999, 91.01, 91.01, 68.75, 68.75]
#
# Recall:
#  73.67
# Recall list [66.67, 65.0, 94.0, 93.0, 93.0, 73.67, 73.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69        30
#            1       0.93      0.54      0.68        50
#
#     accuracy                           0.69        80
#    macro avg       0.74      0.74      0.69        80
# weighted avg       0.79      0.69      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# # MODEL EVALUATION

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[0],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[0],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[0],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[0],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[0],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
accuracy_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
accuracy_matrix
# Out:
#   features     rf     dt     lr    knn    svm
# 0        4  93.75  93.75  93.75  93.44  62.81
# 1        5  93.44  89.69  94.06  92.19  62.19
# 2        6  95.62  92.81  93.44  93.12  91.88
# 3        7  95.94  93.12  93.44  88.75  88.44
# 4        9  95.62  93.75  93.44  88.75  87.81
# 5       15  96.25  93.12  92.50  72.19  67.81
# 6       18  97.81  96.25  91.25  72.19  67.81

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Accuracy')

plt.xlabel('Features')
plt.ylabel('Accuracy')

# show the plot
plt.show()

# %% [markdown]
# ## Precision

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[1],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[1],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[1],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[1],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[1],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
precision_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
precision_matrix
# Out:
#   features      rf     dt     lr    knn    svm
# 0        4   98.39  96.88  98.39  96.88  85.71
# 1        5   98.39  95.45  98.39  95.45  85.21
# 2        6   98.39  95.45  98.39  94.12  91.67
# 3        7   98.39  94.27  98.39  90.54  90.54
# 4        9   98.39  91.56  96.88  90.54  90.54
# 5       15   98.39  95.45  94.67  74.94  74.00
# 6       18  100.00  96.88  93.12  74.94  74.00

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
precision_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
precision_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
precision_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
precision_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
precision_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Precision')

plt.xlabel('Features')
plt.ylabel('Precision')

# show the plot
plt.show()

# %% [markdown]
# ## F1

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[2],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[2],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[2],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[2],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[2],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
F1_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
F1_matrix
# Out:
#   features      rf     dt     lr    knn    svm
# 0        4   98.68  97.37  98.68  97.37  66.67
# 1        5   98.68  96.07  98.68  96.07  64.40
# 2        6   98.68  96.07  98.68  94.79  92.26
# 3        7   98.68  94.73  98.68  91.01  91.01
# 4        9   98.68  92.19  97.37  91.01  91.01
# 5       15   98.68  96.07  94.67  72.43  68.75
# 6       18  100.00  97.37  93.38  72.43  68.75

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
F1_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
F1_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
F1_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
F1_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
F1_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and F1-score')

plt.xlabel('Features')
plt.ylabel('F1-score')

# show the plot
plt.show()

# %% [markdown]
# ## Recall

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[3],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[3],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[3],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[3],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[3],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
recall_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
recall_matrix
# Out:
#   features     rf     dt     lr   knn    svm
# 0        4   99.0  98.00  99.00  98.0  66.67
# 1        5   99.0  97.00  99.00  97.0  65.00
# 2        6   99.0  97.00  99.00  96.0  94.00
# 3        7   99.0  95.33  99.00  93.0  93.00
# 4        9   99.0  93.33  98.00  93.0  93.00
# 5       15   99.0  97.00  94.67  76.0  73.67
# 6       18  100.0  98.00  93.67  76.0  73.67

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
recall_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
recall_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
recall_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
recall_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
recall_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Recall')

plt.xlabel('Features')
plt.ylabel('Recall')

# show the plot
plt.show()
