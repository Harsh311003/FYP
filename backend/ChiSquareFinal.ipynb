# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv('.\chronic_kidney_disease.csv')

# %% [markdown]
# # Analyzing the data

# %%
df.head()
# Out:
#   age  bp     sg al su  rbc  pc  pcc  ba  bgr  ... pcv  wbcc rbcc htn dm  cad  \
# 0  48  80   1.02  1  0    0   0    1   1  121  ...  44  7800  5.2   0  0    1
# 1   7  50   1.02  4  0    0   0    1   1    ?  ...  38  6000  0.0   1  1    1
# 2  62  80   1.01  2  3    0   0    1   1  423  ...  31  7500  0.0   1  0    1
# 3  48  70  1.005  4  0    0   1    0   1  117  ...  32  6700  3.9   0  1    1
# 4  51  80   1.01  2  0    0   0    1   1  106  ...  35  7300  4.6   1  1    1
#
#    appet  pe  ane  class
# 0      1   1    1    ckd
# 1      1   1    1    ckd
# 2      0   1    0    ckd
# 3      0   0    0    ckd
# 4      1   1    1    ckd
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     400 non-null    object
#  1   bp      400 non-null    object
#  2   sg      400 non-null    object
#  3   al      400 non-null    object
#  4   su      400 non-null    object
#  5   rbc     400 non-null    int64
#  6   pc      400 non-null    int64
#  7   pcc     400 non-null    int64
#  8   ba      400 non-null    int64
#  9   bgr     400 non-null    object
#  10  bu      400 non-null    object
#  11  sc      400 non-null    object
#  12  sod     400 non-null    object
#  13  pot     400 non-null    object
#  14  hemo    400 non-null    object
#  15  pcv     400 non-null    int64
#  16  wbcc    400 non-null    int64
#  17  rbcc    400 non-null    float64
#  18  htn     400 non-null    int64
#  19  dm      400 non-null    int64
#  20  cad     400 non-null    int64
#  21  appet   400 non-null    int64
#  22  pe      400 non-null    int64
#  23  ane     400 non-null    int64
#  24  class   400 non-null    object
# dtypes: float64(1), int64(12), object(12)
# memory usage: 78.2+ KB

# %% [markdown]
# # Database loading and pre-processing

# %%
#from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

#Create function for checking missing values which accepts a dataframe as its parameter
def null_values_check(df): 
    #Error handling to prevent abnormal termination of operation
    try:
        #if-else statement for null value check 
        if(df.isnull().values.any() == True):
            #if there are null values present, print a column-wise summary of records with null values
            print('Number of null records within each column:\n' + str(df.isnull().sum()))
        else:
            print('There is no missing values in the dataset.')
    
    except Exception as e:
        logging.error(e)

#initialise variable with dataset name
dataset_name = '.\chronic_kidney_disease.csv'

#error-handling to prevent abnormal termination of code
try:
    #import and load weather dataset into pandas dataframe
    chronic_kidney_disease_dataframe = pd.read_csv(dataset_name)
    
    #Description of Datasets
    #Print number of records and attributes of whole kidney dataset
    print('Shape of dataset: ' + str(chronic_kidney_disease_dataframe.shape))
    print('Total number of records in dataset = ' + str(chronic_kidney_disease_dataframe.shape[0]))
    print('Total number of attributes in dataset = ' + str(chronic_kidney_disease_dataframe.shape[1]))
    print('')
    #call function created to check for null values
    null_values_check(chronic_kidney_disease_dataframe)
    #Missing value imputation
    #replace ? to nan values 
    chronic_kidney_disease_dataframe = chronic_kidney_disease_dataframe.replace('?', np.nan)
    
    
    #set the features and the target variables
    target_class = chronic_kidney_disease_dataframe['class']
    print('\nAre there missing values in Target Class? ' + str(target_class.isna().any()))
    feature_classes = chronic_kidney_disease_dataframe.iloc[:, 0:24]
    print('\nAre there missing values in the Features? \n' + str(feature_classes.isna().any()))
    
    # replacing the null values
    #KNN imputation (n_neighbour = 5 means that the missing values will be replaced by the mean value of 5 nearest neighbors)
    knn_missing_values_imputer = KNNImputer(n_neighbors=5)
    feature_classes = pd.DataFrame(knn_missing_values_imputer.fit_transform(feature_classes),
                                   columns = feature_classes.columns)
    print('\nNow, Are there any missing values in Features? ' + str(feature_classes.isna().any()))
    
    
    #Scaling and normalization of features
    standard_feature_scaler = StandardScaler()
    feature_classes = standard_feature_scaler.fit_transform(feature_classes)
    feature_classes = pd.DataFrame(feature_classes, columns=['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 
                                                             'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 
                                                             'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 
                                                             'cad', 'appet', 'pe', 'ane'])
    
    #Encoding target class using label encoding
    target_label_encoder = preprocessing.LabelEncoder()
    target_class = target_label_encoder.fit_transform(target_class)
    #target_class1 = pd.DataFrame(target_class, columns=['class'])
    
    X=feature_classes
    y=target_class
    
    #split the dataset into training and testing data using K Fold Approach
    kf = StratifiedKFold(n_splits=5, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
        
    print('\nAfter Pre-processing:')
    print('Size of train dataset: ' + str(X_train.shape[0]))
    print('Size of test dataset: ' + str(y_test.shape[0]))
                                                      
except FileNotFoundError as e:
    logging.error(e)
# Out:
# Shape of dataset: (400, 25)
# Total number of records in dataset = 400
# Total number of attributes in dataset = 25
#
# There is no missing values in the dataset.
#
# Are there missing values in Target Class? False
#
# Are there missing values in the Features?
# age       True
# bp        True
# sg        True
# al        True
# su        True
# rbc      False
# pc       False
# pcc      False
# ba       False
# bgr       True
# bu        True
# sc        True
# sod       True
# pot       True
# hemo      True
# pcv      False
# wbcc     False
# rbcc     False
# htn      False
# dm       False
# cad      False
# appet    False
# pe       False
# ane      False
# dtype: bool
#
# Now, Are there any missing values in Features? age      False
# bp       False
# sg       False
# al       False
# su       False
# rbc      False
# pc       False
# pcc      False
# ba       False
# bgr      False
# bu       False
# sc       False
# sod      False
# pot      False
# hemo     False
# pcv      False
# wbcc     False
# rbcc     False
# htn      False
# dm       False
# cad      False
# appet    False
# pe       False
# ane      False
# dtype: bool
#
# After Pre-processing:
# Size of train dataset: 320
# Size of test dataset: 80

# %% [markdown]
# # Converting each column to float data type

# %%
# taking the length of the column and converting the each column to float
colLength = (len(chronic_kidney_disease_dataframe.axes[1]))

# for storing the position of each column
count=0;

for i in chronic_kidney_disease_dataframe:
    count += 1
    # the last column of the data set is label so when we reach last column just break the loop
    if(count==25):
        break
    
    # converting each column to float data type
    
    chronic_kidney_disease_dataframe[i] = chronic_kidney_disease_dataframe[i].astype('float64')

# %%
chronic_kidney_disease_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     391 non-null    float64
#  1   bp      388 non-null    float64
#  2   sg      353 non-null    float64
#  3   al      354 non-null    float64
#  4   su      351 non-null    float64
#  5   rbc     400 non-null    float64
#  6   pc      400 non-null    float64
#  7   pcc     400 non-null    float64
#  8   ba      400 non-null    float64
#  9   bgr     356 non-null    float64
#  10  bu      381 non-null    float64
#  11  sc      383 non-null    float64
#  12  sod     313 non-null    float64
#  13  pot     312 non-null    float64
#  14  hemo    348 non-null    float64
#  15  pcv     400 non-null    float64
#  16  wbcc    400 non-null    float64
#  17  rbcc    400 non-null    float64
#  18  htn     400 non-null    float64
#  19  dm      400 non-null    float64
#  20  cad     400 non-null    float64
#  21  appet   400 non-null    float64
#  22  pe      400 non-null    float64
#  23  ane     400 non-null    float64
#  24  class   400 non-null    object
# dtypes: float64(24), object(1)
# memory usage: 78.2+ KB

# %%
chronic_kidney_disease_dataframe['class'].value_counts()
chronic_kidney_disease_dataframe['class'] = chronic_kidney_disease_dataframe['class'].replace(to_replace={'ckd\t':'ckd'})
chronic_kidney_disease_dataframe["class"] = [1 if i == "ckd" else 0 for i in chronic_kidney_disease_dataframe["class"]]
features = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
           'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
           'appet', 'pe', 'ane']

# %% [markdown]
# # Filling empty cell or null values with median

# %%
for feature in features:
    chronic_kidney_disease_dataframe[feature] = chronic_kidney_disease_dataframe[feature].fillna(chronic_kidney_disease_dataframe[feature].median())

# %% [markdown]
# # Checking For Null Values

# %%
chronic_kidney_disease_dataframe.isnull().any().sum()
# Out:
# 0

# %%
# Relacing negative values to positive
X_train =np.where(X_train <0, X_train*-1, X_train)

# %%
# # Converting numpy array to pandas dataframe
X_train = pd.DataFrame(X_train)
for i in range(0,len(features)):
    X_train = X_train.rename(columns = {i:features[i]})
X_train
# Out:
#           age        bp        sg        al        su      rbc        pc  \
# 0    0.198844  0.264037  0.502114  0.023156  0.431146  0.36489  0.484322
# 1    2.604457  1.957875  0.502114  2.292428  0.431146  0.36489  0.484322
# 2    0.622584  0.264037  1.320442  0.748706  2.433610  0.36489  0.484322
# 3    0.198844  0.476600  2.231720  2.292428  0.431146  0.36489  2.064742
# 4    0.022824  0.264037  1.320442  0.748706  0.431146  0.36489  0.484322
# ..        ...       ...       ...       ...       ...      ...       ...
# 315  1.607008  0.264037  0.502114  0.795017  0.431146  0.36489  0.484322
# 316  0.505237  0.264037  1.413392  0.795017  0.431146  0.36489  0.484322
# 317  0.974625  1.217238  1.413392  0.795017  0.431146  0.36489  0.484322
# 318  1.254967  0.264037  1.413392  0.795017  0.431146  0.36489  0.484322
# 319  1.385339  0.476600  0.502114  0.795017  0.431146  0.36489  0.484322
#
#           pcc        ba       bgr  ...      hemo       pcv      wbcc  \
# 0    0.360477  0.263664  0.369773  ...  1.111940  0.709349  0.361549
# 1    0.360477  0.263664  0.367144  ...  0.339078  0.355191  0.039800
# 2    0.360477  0.263664  3.600419  ...  0.940720  0.057993  0.294657
# 3    2.774104  0.263664  0.422359  ...  0.374469  0.001033  0.116280
# 4    0.360477  0.263664  0.566968  ...  0.232906  0.178112  0.250063
# ..        ...       ...       ...  ...       ...       ...       ...
# 315  0.360477  0.263664  0.737871  ...  0.064376  1.887811  1.008167
# 316  0.360477  0.263664  0.895627  ...  0.970378  0.827402  0.963572
# 317  0.360477  0.263664  0.317188  ...  1.819754  1.063508  0.116280
# 318  0.360477  0.263664  0.882480  ...  0.934987  0.768376  0.718303
# 319  0.360477  0.263664  0.553822  ...  0.474908  0.827402  0.918978
#
#          rbcc       htn        dm       cad     appet        pe       ane
# 0    0.860785  1.297907  1.347925  0.323994  0.511693  0.488252  0.424195
# 1    1.339575  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# 2    1.339575  0.770471  1.347925  0.323994  1.954297  0.488252  2.357409
# 3    0.310695  1.297907  0.741881  0.323994  1.954297  2.048122  2.357409
# 4    0.606897  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# ..        ...       ...       ...       ...       ...       ...       ...
# 315  1.326245  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# 316  0.903099  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# 317  1.241616  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# 318  1.156987  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
# 319  0.691526  0.770471  0.741881  0.323994  0.511693  0.488252  0.424195
#
# [320 rows x 24 columns]

# %% [markdown]
# # Chi Square Feature Selection

# %%
## Perform chi2 test
### chi2 returns 2 values
### Fscore and the pvalue
from sklearn.feature_selection import chi2
f_p_values=chi2(X_train,y_train)

# %%
f_p_values
# Out:
# (array([1.17388998e-01, 4.17634476e+00, 2.43299381e-01, 8.81318365e-01,
#         1.69818034e+01, 2.65788878e+01, 2.33671021e+01, 1.41934602e+01,
#         5.03459730e+00, 8.62357909e+00, 1.00043392e+01, 4.22671349e+00,
#         2.98418578e-04, 7.83694163e+00, 4.72978298e+00, 9.81440705e-01,
#         2.42782469e+01, 7.63851392e-01, 6.64279288e+00, 8.07609635e+00,
#         1.39540797e+01, 2.34894202e+01, 1.97610061e+01, 2.01646627e+01]),
#  array([7.31883768e-01, 4.09920198e-02, 6.21833218e-01, 3.47840844e-01,
#         3.77397878e-05, 2.52993340e-07, 1.33848164e-06, 1.64942782e-04,
#         2.48458625e-02, 3.31839186e-03, 1.56171814e-03, 3.97924215e-02,
#         9.86217392e-01, 5.11891398e-03, 2.96446254e-02, 3.21843378e-01,
#         8.33753545e-07, 3.82125920e-01, 9.95577380e-03, 4.48529624e-03,
#         1.87330673e-04, 1.25602563e-06, 8.77548821e-06, 7.10534853e-06]))

# %%
#p-values
p_values=pd.Series(f_p_values[1])
p_values.index=  X_train.columns
p_values.index
p_values
# Out:
# age      7.318838e-01
# bp       4.099202e-02
# sg       6.218332e-01
# al       3.478408e-01
# su       3.773979e-05
# rbc      2.529933e-07
# pc       1.338482e-06
# pcc      1.649428e-04
# ba       2.484586e-02
# bgr      3.318392e-03
# bu       1.561718e-03
# sc       3.979242e-02
# sod      9.862174e-01
# pot      5.118914e-03
# hemo     2.964463e-02
# pcv      3.218434e-01
# wbcc     8.337535e-07
# rbcc     3.821259e-01
# htn      9.955774e-03
# dm       4.485296e-03
# cad      1.873307e-04
# appet    1.256026e-06
# pe       8.775488e-06
# ane      7.105349e-06
# dtype: float64

# %%
df2 = pd.DataFrame(p_values)
df2 = df2.rename(columns = {0:'p_values'})
df2
# Out:
#            p_values
# age    7.318838e-01
# bp     4.099202e-02
# sg     6.218332e-01
# al     3.478408e-01
# su     3.773979e-05
# rbc    2.529933e-07
# pc     1.338482e-06
# pcc    1.649428e-04
# ba     2.484586e-02
# bgr    3.318392e-03
# bu     1.561718e-03
# sc     3.979242e-02
# sod    9.862174e-01
# pot    5.118914e-03
# hemo   2.964463e-02
# pcv    3.218434e-01
# wbcc   8.337535e-07
# rbcc   3.821259e-01
# htn    9.955774e-03
# dm     4.485296e-03
# cad    1.873307e-04
# appet  1.256026e-06
# pe     8.775488e-06
# ane    7.105349e-06

# %%
# Sorting in Ascending order & Ploting 
p_values.sort_values(ascending=False).plot.bar(xlabel="Features",ylabel="p_values",figsize=(20, 8))
# Out:
# <AxesSubplot: xlabel='Features', ylabel='p_values'>

# %%
# Independent and Dependent Feature:
X = chronic_kidney_disease_dataframe.iloc[:, :-1]
y = chronic_kidney_disease_dataframe.iloc[:, -1]

# %% [markdown]
# # Function for calling different classifier and splitting of dataset into traning and testing and selecting the best feature from the Chi Square

# %%
# selecting the top feature
from sklearn.feature_selection import SelectKBest
def selectFeature(n):
    sel_n_cols = SelectKBest(chi2, k=n)
    sel_n_cols.fit(X_train, y_train)
    return X_train.columns[sel_n_cols.get_support()]

# for selecting all the details of the dataset based on the selected top feature
# chronic_kidney_disease_dataframe[['sg', 'htn', 'hemo', 'dm', 'al', 'appet', 'rc', 'pc']]
dataset=[]
def topFeature(feature):
    dataset=[]
    topFeature = []
    for i in feature:
        topFeature.append(i)
    dataset.append(topFeature)
    return dataset

# calling classifier
def classifierUsed(selectedDataSetForTraining,feature,number):
    print("Using Random Forest Classification....\n")
    randomForestClassifier(selectedDataSetForTraining,feature,number)    
    print("\nUsing Decision Tree Classification....\n")
    decisionTreeClassifier(selectedDataSetForTraining,feature,number)
    print("\nUsing KNN Classification....\n")
    KNNClassifier(selectedDataSetForTraining,feature,number)
    print("\nUsing Logistic Regression Classification....\n")
    logisticRegressionClassifier(selectedDataSetForTraining,feature,number)
    print("\nUsing SVM Classification....\n")
    supportVectorMachineClassifier(selectedDataSetForTraining,feature,number)


# function for finding number of features for classifier
def numberOfFeatureForClassifier(number):
    selectedFeature = selectFeature(number)
    feature =[]
    for i in selectedFeature:
        # appending the selected feature into a list
        feature.append(i)

    selectedDataSetForTraining = topFeature(feature)
    
    # calling the classifier Used function
    classifierUsed(selectedDataSetForTraining,feature,number)
    
n_Featurelist = []            # To store no of features

# Format: list = [[Accuracy scores],[Percision scores],[F1 scores],[Recall scores]]

rf_list = [[],[],[],[]]       # To store rf performance
dt_list = [[],[],[],[]]       # To store dt performance
lr_list = [[],[],[],[]]       # To store lr performance
knn_list = [[],[],[],[]]      # To store knn performance
svm_list = [[],[],[],[]]      # To store svm performance

# %% [markdown]
# # Random Forest Classifier

# %%
# Random Forest classifier function
from sklearn.ensemble import RandomForestClassifier

def randomForestClassifier(selectedDataSetForTraining,feature,number):
    
    # printing the top feature
    print("Using Random Forest Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5  
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]

    
    # RandomForestClassifier:
    RandomForest = RandomForestClassifier()
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=RandomForest,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending no of features to Feature list 
    n_Featurelist.append(str(number))
    
    # Appending avg accuracy to list 
    rf_list[0].append(avg_Accuracy)
    
    print('Accuracy list {} & No of Feature list {}'.format(rf_list[0],n_Featurelist))
    
    RandomForest = RandomForest.fit(X_train,y_train)
    
    # Predictions:
    y_pred=RandomForest.predict(X_test)

    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    rf_list[1].append(precision_score)
    print('Precision list',rf_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    rf_list[2].append(f1_score)
    print('F1-score list',rf_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    rf_list[3].append(recall_score)
    print('Recall list',rf_list[3])
    
    print()
    
    print('\nClassification Report:\n',metrics.classification_report(y_test,y_pred))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Decision Tree Classifier

# %%
# Decision Tree Classifier:
from sklearn.tree import DecisionTreeClassifier

def decisionTreeClassifier(selectedDataSetForTraining,feature,number):

     # printing the top feature
    print("Using Decision Tree Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    
    # Decision Tree Classifier:
    decision_tree_model = DecisionTreeClassifier(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=decision_tree_model,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending avg accuracy to list
    dt_list[0].append(avg_Accuracy)
    print('Accuracy list',(dt_list[0]))
    
    decision_tree_model = decision_tree_model.fit(X_train,y_train)

    #DT predictions on test features
    y_pred = decision_tree_model.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to listv
    dt_list[1].append(precision_score)
    print('Precision list',dt_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    dt_list[2].append(f1_score)
    print('F1-score list',dt_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    dt_list[3].append(recall_score)
    print('Recall list',dt_list[3])
    
    print()
    
     #display classification report for Decision Tree
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))

    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # KNN Classifier

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

def KNNClassifier(selectedDataSetForTraining,feature,number):

    print("Using KNN Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    #KNN Classifier:
    KNN_classifier = KNeighborsClassifier(n_neighbors=5)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=KNN_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)
    
    # Appending avg accuracy to list
    knn_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(knn_list[0]))
    
    KNN_classifier = KNN_classifier.fit(X_train,y_train)

    #KNN predictions on test features
    y_pred = KNN_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    knn_list[1].append(precision_score)
    print('Precision list',knn_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    knn_list[2].append(f1_score)
    print('F1-score list',knn_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    knn_list[3].append(recall_score)
    print('Recall list',knn_list[3])
    
    print()
    
     #display classification report for KNN
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))

    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Logistic Regression Classifier

# %%
#Logistic Regression Classification
from sklearn.linear_model import LogisticRegression 

def logisticRegressionClassifier(selectedDataSetForTraining,feature,number):

    # printing the top feature
    print("Using Logistic Regression Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()
    
    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
        
    #Logistic Regression Classifier:    
    LR_classifier = LogisticRegression(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=LR_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)

    # Appending avg accuracy to list
    lr_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(lr_list[0]))
    
    LR_classifier.fit(X_train,y_train)

    #LR predictions on test features
    y_pred = LR_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    lr_list[1].append(precision_score)
    print('Precision list',lr_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    lr_list[2].append(f1_score)
    print('F1-score list',lr_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    lr_list[3].append(recall_score)
    print('Recall list',lr_list[3])
    print()
    
    #display classification report for LR
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Support Vector Machine Classifier

# %%
#Support vector machine
from sklearn.svm import SVC

def supportVectorMachineClassifier(selectedDataSetForTraining,feature,number):
    
    # printing the top feature
    print("Using Support vector machine Classification")
    print(f"The top {number} features are: ")
    print(feature)
    print()

    # Splitting of dataset using K Fold Validation Approach:
    
    X = chronic_kidney_disease_dataframe[selectedDataSetForTraining[0]]
    k = 5
    kf = StratifiedKFold(n_splits=k, random_state=None)
    for train_index , test_index in kf.split(X,y):
        X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
        y_train , y_test = y[train_index] , y[test_index]
    
    # Support Vector Machine Classifier :
    
    SVM_classifier = support_vector_machine_model = SVC(random_state = 0)
        
    #running the model using scoring metric as accuracy
    kf_result=cross_val_score(estimator=SVM_classifier,X=X_train,y=y_train, cv=kf)
    print('Accuracy of {} fold - {}'.format(k,kf_result))
    
    # calculating the Average accuracy
    avg_Accuracy = (np.round(kf_result.mean(),4))*100
    print('Accuracy with k fold validation', avg_Accuracy)

    # Appending avg accuracy to list
    svm_list[0].append(avg_Accuracy)
    
    print('Accuracy list',(svm_list[0]))
    
    SVM_classifier.fit(X_train,y_train)

    #svm predictions on test features
    y_pred = SVM_classifier.predict(X_test)
    
    # confusion matrix
    print('\nConfusion matrix:\n',metrics.confusion_matrix(y_test,y_pred))
    print()
    
    #Performance
    # calculating the Precision score
    precision_score = (round(metrics.precision_score(y_test,y_pred,average='macro'),4))*100
    print('\nPrecision :\n',precision_score)
    
    # Appending Precision score to list
    svm_list[1].append(precision_score)
    print('Precision list',svm_list[1])
    
    # calculating the F1 score
    f1_score = (round(metrics.f1_score(y_test,y_pred,average='macro'),4))*100
    print('\nF1-score:\n',f1_score)
    
    # Appending F1 score to list
    svm_list[2].append(f1_score)
    print('F1-score list',svm_list[2])
    
    # calculating the Recall score
    recall_score = (round(metrics.recall_score(y_test,y_pred,average='macro'),4))*100
    print('\nRecall:\n',recall_score)
    
    # Appending Recall to list
    svm_list[3].append(recall_score)
    print('Recall list',svm_list[3])
    
    print()
    
     #display classification report for SVM 
    print('\nClassification Report:\n' + str(metrics.classification_report(y_test, y_pred)))
    print("---------------------------------------------------------------------")
    print()

# %% [markdown]
# # Calling The Model

# %% [markdown]
# ## No of features used:4

# %%
numberOfFeatureForClassifier(4)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 4 features are:
# ['rbc', 'pc', 'wbcc', 'appet']
#
# Accuracy of 5 fold - [0.84375  0.765625 0.84375  0.875    0.875   ]
# Accuracy with k fold validation 84.06
# Accuracy list [84.06] & No of Feature list ['4']
#
# Confusion matrix:
#  [[24  6]
#  [11 39]]
#
#
# Precision :
#  77.62
# Precision list [77.62]
#
# F1-score:
#  77.98
# F1-score list [77.98]
#
# Recall:
#  79.0
# Recall list [79.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74        30
#            1       0.87      0.78      0.82        50
#
#     accuracy                           0.79        80
#    macro avg       0.78      0.79      0.78        80
# weighted avg       0.80      0.79      0.79        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 4 features are:
# ['rbc', 'pc', 'wbcc', 'appet']
#
# Accuracy of 5 fold - [0.84375  0.765625 0.859375 0.890625 0.875   ]
# Accuracy with k fold validation 84.69
# Accuracy list [84.69]
#
# Confusion matrix:
#  [[24  6]
#  [11 39]]
#
#
# Precision :
#  77.62
# Precision list [77.62]
#
# F1-score:
#  77.98
# F1-score list [77.98]
#
# Recall:
#  79.0
# Recall list [79.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74        30
#            1       0.87      0.78      0.82        50
#
#     accuracy                           0.79        80
#    macro avg       0.78      0.79      0.78        80
# weighted avg       0.80      0.79      0.79        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 4 features are:
# ['rbc', 'pc', 'wbcc', 'appet']
#
# Accuracy of 5 fold - [0.546875 0.671875 0.625    0.71875  0.734375]
# Accuracy with k fold validation 65.94
# Accuracy list [65.94]
#
# Confusion matrix:
#  [[27  3]
#  [18 32]]
#
#
# Precision :
#  75.71
# Precision list [75.71]
#
# F1-score:
#  73.65
# F1-score list [73.65]
#
# Recall:
#  77.0
# Recall list [77.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.90      0.72        30
#            1       0.91      0.64      0.75        50
#
#     accuracy                           0.74        80
#    macro avg       0.76      0.77      0.74        80
# weighted avg       0.80      0.74      0.74        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 4 features are:
# ['rbc', 'pc', 'wbcc', 'appet']
#
# Accuracy of 5 fold - [0.859375 0.625    0.765625 0.640625 0.84375 ]
# Accuracy with k fold validation 74.69
# Accuracy list [74.69]
#
# Confusion matrix:
#  [[ 0 30]
#  [ 0 50]]
#
#
# Precision :
#  31.25
# Precision list [31.25]
#
# F1-score:
#  38.46
# F1-score list [38.46]
#
# Recall:
#  50.0
# Recall list [50.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.62      1.00      0.77        50
#
#     accuracy                           0.62        80
#    macro avg       0.31      0.50      0.38        80
# weighted avg       0.39      0.62      0.48        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 4 features are:
# ['rbc', 'pc', 'wbcc', 'appet']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81]
#
# Confusion matrix:
#  [[28  2]
#  [23 27]]
#
#
# Precision :
#  74.0
# Precision list [74.0]
#
# F1-score:
#  68.75
# F1-score list [68.75]
#
# Recall:
#  73.67
# Recall list [73.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69        30
#            1       0.93      0.54      0.68        50
#
#     accuracy                           0.69        80
#    macro avg       0.74      0.74      0.69        80
# weighted avg       0.79      0.69      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:5

# %%
numberOfFeatureForClassifier(5)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 5 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'ane']
#
# Accuracy of 5 fold - [0.859375 0.796875 0.84375  0.859375 0.875   ]
# Accuracy with k fold validation 84.69
# Accuracy list [84.06, 84.69] & No of Feature list ['4', '5']
#
# Confusion matrix:
#  [[26  4]
#  [ 9 41]]
#
#
# Precision :
#  82.69999999999999
# Precision list [77.62, 82.69999999999999]
#
# F1-score:
#  83.16
# F1-score list [77.98, 83.16]
#
# Recall:
#  84.33
# Recall list [79.0, 84.33]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        30
#            1       0.91      0.82      0.86        50
#
#     accuracy                           0.84        80
#    macro avg       0.83      0.84      0.83        80
# weighted avg       0.85      0.84      0.84        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 5 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'ane']
#
# Accuracy of 5 fold - [0.859375 0.796875 0.859375 0.890625 0.875   ]
# Accuracy with k fold validation 85.61999999999999
# Accuracy list [84.69, 85.61999999999999]
#
# Confusion matrix:
#  [[26  4]
#  [ 9 41]]
#
#
# Precision :
#  82.69999999999999
# Precision list [77.62, 82.69999999999999]
#
# F1-score:
#  83.16
# F1-score list [77.98, 83.16]
#
# Recall:
#  84.33
# Recall list [79.0, 84.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        30
#            1       0.91      0.82      0.86        50
#
#     accuracy                           0.84        80
#    macro avg       0.83      0.84      0.83        80
# weighted avg       0.85      0.84      0.84        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 5 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'ane']
#
# Accuracy of 5 fold - [0.53125  0.640625 0.625    0.734375 0.734375]
# Accuracy with k fold validation 65.31
# Accuracy list [65.94, 65.31]
#
# Confusion matrix:
#  [[28  2]
#  [20 30]]
#
#
# Precision :
#  76.03999999999999
# Precision list [75.71, 76.03999999999999]
#
# F1-score:
#  72.48
# F1-score list [73.65, 72.48]
#
# Recall:
#  76.67
# Recall list [77.0, 76.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        30
#            1       0.94      0.60      0.73        50
#
#     accuracy                           0.73        80
#    macro avg       0.76      0.77      0.72        80
# weighted avg       0.80      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 5 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'ane']
#
# Accuracy of 5 fold - [0.859375 0.625    0.796875 0.890625 0.859375]
# Accuracy with k fold validation 80.62
# Accuracy list [74.69, 80.62]
#
# Confusion matrix:
#  [[ 0 30]
#  [ 0 50]]
#
#
# Precision :
#  31.25
# Precision list [31.25, 31.25]
#
# F1-score:
#  38.46
# F1-score list [38.46, 38.46]
#
# Recall:
#  50.0
# Recall list [50.0, 50.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.62      1.00      0.77        50
#
#     accuracy                           0.62        80
#    macro avg       0.31      0.50      0.38        80
# weighted avg       0.39      0.62      0.48        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 5 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [24 26]]
#
#
# Precision :
#  73.35000000000001
# Precision list [74.0, 73.35000000000001]
#
# F1-score:
#  67.47999999999999
# F1-score list [68.75, 67.47999999999999]
#
# Recall:
#  72.67
# Recall list [73.67, 72.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.93      0.68        30
#            1       0.93      0.52      0.67        50
#
#     accuracy                           0.68        80
#    macro avg       0.73      0.73      0.67        80
# weighted avg       0.78      0.68      0.67        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:6

# %%
numberOfFeatureForClassifier(6)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 6 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.828125 0.8125   0.84375  0.875    0.90625 ]
# Accuracy with k fold validation 85.31
# Accuracy list [84.06, 84.69, 85.31] & No of Feature list ['4', '5', '6']
#
# Confusion matrix:
#  [[26  4]
#  [ 9 41]]
#
#
# Precision :
#  82.69999999999999
# Precision list [77.62, 82.69999999999999, 82.69999999999999]
#
# F1-score:
#  83.16
# F1-score list [77.98, 83.16, 83.16]
#
# Recall:
#  84.33
# Recall list [79.0, 84.33, 84.33]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        30
#            1       0.91      0.82      0.86        50
#
#     accuracy                           0.84        80
#    macro avg       0.83      0.84      0.83        80
# weighted avg       0.85      0.84      0.84        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 6 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.875    0.8125   0.859375 0.921875 0.890625]
# Accuracy with k fold validation 87.19
# Accuracy list [84.69, 85.61999999999999, 87.19]
#
# Confusion matrix:
#  [[26  4]
#  [ 9 41]]
#
#
# Precision :
#  82.69999999999999
# Precision list [77.62, 82.69999999999999, 82.69999999999999]
#
# F1-score:
#  83.16
# F1-score list [77.98, 83.16, 83.16]
#
# Recall:
#  84.33
# Recall list [79.0, 84.33, 84.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        30
#            1       0.91      0.82      0.86        50
#
#     accuracy                           0.84        80
#    macro avg       0.83      0.84      0.83        80
# weighted avg       0.85      0.84      0.84        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 6 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.546875 0.640625 0.640625 0.734375 0.734375]
# Accuracy with k fold validation 65.94
# Accuracy list [65.94, 65.31, 65.94]
#
# Confusion matrix:
#  [[28  2]
#  [20 30]]
#
#
# Precision :
#  76.03999999999999
# Precision list [75.71, 76.03999999999999, 76.03999999999999]
#
# F1-score:
#  72.48
# F1-score list [73.65, 72.48, 72.48]
#
# Recall:
#  76.67
# Recall list [77.0, 76.67, 76.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        30
#            1       0.94      0.60      0.73        50
#
#     accuracy                           0.73        80
#    macro avg       0.76      0.77      0.72        80
# weighted avg       0.80      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 6 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.859375 0.625    0.796875 0.890625 0.875   ]
# Accuracy with k fold validation 80.94
# Accuracy list [74.69, 80.62, 80.94]
#
# Confusion matrix:
#  [[ 0 30]
#  [ 0 50]]
#
#
# Precision :
#  31.25
# Precision list [31.25, 31.25, 31.25]
#
# F1-score:
#  38.46
# F1-score list [38.46, 38.46, 38.46]
#
# Recall:
#  50.0
# Recall list [50.0, 50.0, 50.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.62      1.00      0.77        50
#
#     accuracy                           0.62        80
#    macro avg       0.31      0.50      0.38        80
# weighted avg       0.39      0.62      0.48        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 6 features are:
# ['rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [24 26]]
#
#
# Precision :
#  73.35000000000001
# Precision list [74.0, 73.35000000000001, 73.35000000000001]
#
# F1-score:
#  67.47999999999999
# F1-score list [68.75, 67.47999999999999, 67.47999999999999]
#
# Recall:
#  72.67
# Recall list [73.67, 72.67, 72.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.93      0.68        30
#            1       0.93      0.52      0.67        50
#
#     accuracy                           0.68        80
#    macro avg       0.73      0.73      0.67        80
# weighted avg       0.78      0.68      0.67        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:7

# %%
numberOfFeatureForClassifier(7)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 7 features are:
# ['su', 'rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.921875 0.875    0.859375 0.90625  0.953125]
# Accuracy with k fold validation 90.31
# Accuracy list [84.06, 84.69, 85.31, 90.31] & No of Feature list ['4', '5', '6', '7']
#
# Confusion matrix:
#  [[26  4]
#  [ 7 43]]
#
#
# Precision :
#  85.14
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 85.14]
#
# F1-score:
#  85.6
# F1-score list [77.98, 83.16, 83.16, 85.6]
#
# Recall:
#  86.33
# Recall list [79.0, 84.33, 84.33, 86.33]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83        30
#            1       0.91      0.86      0.89        50
#
#     accuracy                           0.86        80
#    macro avg       0.85      0.86      0.86        80
# weighted avg       0.87      0.86      0.86        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 7 features are:
# ['su', 'rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.921875 0.875    0.890625 0.921875 0.9375  ]
# Accuracy with k fold validation 90.94
# Accuracy list [84.69, 85.61999999999999, 87.19, 90.94]
#
# Confusion matrix:
#  [[26  4]
#  [ 8 42]]
#
#
# Precision :
#  83.89
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 83.89]
#
# F1-score:
#  84.38
# F1-score list [77.98, 83.16, 83.16, 84.38]
#
# Recall:
#  85.33
# Recall list [79.0, 84.33, 84.33, 85.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        30
#            1       0.91      0.84      0.87        50
#
#     accuracy                           0.85        80
#    macro avg       0.84      0.85      0.84        80
# weighted avg       0.86      0.85      0.85        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 7 features are:
# ['su', 'rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.59375  0.640625 0.65625  0.75     0.734375]
# Accuracy with k fold validation 67.5
# Accuracy list [65.94, 65.31, 65.94, 67.5]
#
# Confusion matrix:
#  [[28  2]
#  [20 30]]
#
#
# Precision :
#  76.03999999999999
# Precision list [75.71, 76.03999999999999, 76.03999999999999, 76.03999999999999]
#
# F1-score:
#  72.48
# F1-score list [73.65, 72.48, 72.48, 72.48]
#
# Recall:
#  76.67
# Recall list [77.0, 76.67, 76.67, 76.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        30
#            1       0.94      0.60      0.73        50
#
#     accuracy                           0.73        80
#    macro avg       0.76      0.77      0.72        80
# weighted avg       0.80      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 7 features are:
# ['su', 'rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.921875 0.875    0.84375  0.875    0.9375  ]
# Accuracy with k fold validation 89.05999999999999
# Accuracy list [74.69, 80.62, 80.94, 89.05999999999999]
#
# Confusion matrix:
#  [[30  0]
#  [ 7 43]]
#
#
# Precision :
#  90.53999999999999
# Precision list [31.25, 31.25, 31.25, 90.53999999999999]
#
# F1-score:
#  91.01
# F1-score list [38.46, 38.46, 38.46, 91.01]
#
# Recall:
#  93.0
# Recall list [50.0, 50.0, 50.0, 93.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        30
#            1       1.00      0.86      0.92        50
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.93      0.91        80
# weighted avg       0.93      0.91      0.91        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 7 features are:
# ['su', 'rbc', 'pc', 'wbcc', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [24 26]]
#
#
# Precision :
#  73.35000000000001
# Precision list [74.0, 73.35000000000001, 73.35000000000001, 73.35000000000001]
#
# F1-score:
#  67.47999999999999
# F1-score list [68.75, 67.47999999999999, 67.47999999999999, 67.47999999999999]
#
# Recall:
#  72.67
# Recall list [73.67, 72.67, 72.67, 72.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.93      0.68        30
#            1       0.93      0.52      0.67        50
#
#     accuracy                           0.68        80
#    macro avg       0.73      0.73      0.67        80
# weighted avg       0.78      0.68      0.67        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:9

# %%
numberOfFeatureForClassifier(9)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 9 features are:
# ['su', 'rbc', 'pc', 'pcc', 'wbcc', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.875    0.84375  0.859375 0.875    0.953125]
# Accuracy with k fold validation 88.12
# Accuracy list [84.06, 84.69, 85.31, 90.31, 88.12] & No of Feature list ['4', '5', '6', '7', '9']
#
# Confusion matrix:
#  [[26  4]
#  [ 6 44]]
#
#
# Precision :
#  86.46000000000001
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 85.14, 86.46000000000001]
#
# F1-score:
#  86.83
# F1-score list [77.98, 83.16, 83.16, 85.6, 86.83]
#
# Recall:
#  87.33
# Recall list [79.0, 84.33, 84.33, 86.33, 87.33]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84        30
#            1       0.92      0.88      0.90        50
#
#     accuracy                           0.88        80
#    macro avg       0.86      0.87      0.87        80
# weighted avg       0.88      0.88      0.88        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 9 features are:
# ['su', 'rbc', 'pc', 'pcc', 'wbcc', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.875   0.84375 0.875   0.90625 0.9375 ]
# Accuracy with k fold validation 88.75
# Accuracy list [84.69, 85.61999999999999, 87.19, 90.94, 88.75]
#
# Confusion matrix:
#  [[26  4]
#  [ 8 42]]
#
#
# Precision :
#  83.89
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 83.89, 83.89]
#
# F1-score:
#  84.38
# F1-score list [77.98, 83.16, 83.16, 84.38, 84.38]
#
# Recall:
#  85.33
# Recall list [79.0, 84.33, 84.33, 85.33, 85.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        30
#            1       0.91      0.84      0.87        50
#
#     accuracy                           0.85        80
#    macro avg       0.84      0.85      0.84        80
# weighted avg       0.86      0.85      0.85        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 9 features are:
# ['su', 'rbc', 'pc', 'pcc', 'wbcc', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.59375  0.640625 0.625    0.75     0.75    ]
# Accuracy with k fold validation 67.19000000000001
# Accuracy list [65.94, 65.31, 65.94, 67.5, 67.19000000000001]
#
# Confusion matrix:
#  [[28  2]
#  [20 30]]
#
#
# Precision :
#  76.03999999999999
# Precision list [75.71, 76.03999999999999, 76.03999999999999, 76.03999999999999, 76.03999999999999]
#
# F1-score:
#  72.48
# F1-score list [73.65, 72.48, 72.48, 72.48, 72.48]
#
# Recall:
#  76.67
# Recall list [77.0, 76.67, 76.67, 76.67, 76.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.93      0.72        30
#            1       0.94      0.60      0.73        50
#
#     accuracy                           0.73        80
#    macro avg       0.76      0.77      0.72        80
# weighted avg       0.80      0.72      0.73        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 9 features are:
# ['su', 'rbc', 'pc', 'pcc', 'wbcc', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.90625 0.8125  0.84375 0.90625 0.9375 ]
# Accuracy with k fold validation 88.12
# Accuracy list [74.69, 80.62, 80.94, 89.05999999999999, 88.12]
#
# Confusion matrix:
#  [[30  0]
#  [ 9 41]]
#
#
# Precision :
#  88.46000000000001
# Precision list [31.25, 31.25, 31.25, 90.53999999999999, 88.46000000000001]
#
# F1-score:
#  88.53
# F1-score list [38.46, 38.46, 38.46, 91.01, 88.53]
#
# Recall:
#  91.0
# Recall list [50.0, 50.0, 50.0, 93.0, 91.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        30
#            1       1.00      0.82      0.90        50
#
#     accuracy                           0.89        80
#    macro avg       0.88      0.91      0.89        80
# weighted avg       0.91      0.89      0.89        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 9 features are:
# ['su', 'rbc', 'pc', 'pcc', 'wbcc', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81, 67.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [24 26]]
#
#
# Precision :
#  73.35000000000001
# Precision list [74.0, 73.35000000000001, 73.35000000000001, 73.35000000000001, 73.35000000000001]
#
# F1-score:
#  67.47999999999999
# F1-score list [68.75, 67.47999999999999, 67.47999999999999, 67.47999999999999, 67.47999999999999]
#
# Recall:
#  72.67
# Recall list [73.67, 72.67, 72.67, 72.67, 72.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.93      0.68        30
#            1       0.93      0.52      0.67        50
#
#     accuracy                           0.68        80
#    macro avg       0.73      0.73      0.67        80
# weighted avg       0.78      0.68      0.67        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:15

# %%
numberOfFeatureForClassifier(15)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 15 features are:
# ['su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'pot', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.953125 0.90625  0.890625 0.984375 0.953125]
# Accuracy with k fold validation 93.75
# Accuracy list [84.06, 84.69, 85.31, 90.31, 88.12, 93.75] & No of Feature list ['4', '5', '6', '7', '9', '15']
#
# Confusion matrix:
#  [[30  0]
#  [ 4 46]]
#
#
# Precision :
#  94.12
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 85.14, 86.46000000000001, 94.12]
#
# F1-score:
#  94.78999999999999
# F1-score list [77.98, 83.16, 83.16, 85.6, 86.83, 94.78999999999999]
#
# Recall:
#  96.0
# Recall list [79.0, 84.33, 84.33, 86.33, 87.33, 96.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        30
#            1       1.00      0.92      0.96        50
#
#     accuracy                           0.95        80
#    macro avg       0.94      0.96      0.95        80
# weighted avg       0.96      0.95      0.95        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 15 features are:
# ['su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'pot', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.859375 0.875    0.796875 0.90625  0.9375  ]
# Accuracy with k fold validation 87.5
# Accuracy list [84.69, 85.61999999999999, 87.19, 90.94, 88.75, 87.5]
#
# Confusion matrix:
#  [[29  1]
#  [ 6 44]]
#
#
# Precision :
#  90.32
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 83.89, 83.89, 90.32]
#
# F1-score:
#  90.93
# F1-score list [77.98, 83.16, 83.16, 84.38, 84.38, 90.93]
#
# Recall:
#  92.33
# Recall list [79.0, 84.33, 84.33, 85.33, 85.33, 92.33]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89        30
#            1       0.98      0.88      0.93        50
#
#     accuracy                           0.91        80
#    macro avg       0.90      0.92      0.91        80
# weighted avg       0.92      0.91      0.91        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 15 features are:
# ['su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'pot', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.6875  0.71875 0.6875  0.78125 0.71875]
# Accuracy with k fold validation 71.88
# Accuracy list [65.94, 65.31, 65.94, 67.5, 67.19000000000001, 71.88]
#
# Confusion matrix:
#  [[27  3]
#  [18 32]]
#
#
# Precision :
#  75.71
# Precision list [75.71, 76.03999999999999, 76.03999999999999, 76.03999999999999, 76.03999999999999, 75.71]
#
# F1-score:
#  73.65
# F1-score list [73.65, 72.48, 72.48, 72.48, 72.48, 73.65]
#
# Recall:
#  77.0
# Recall list [77.0, 76.67, 76.67, 76.67, 76.67, 77.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.90      0.72        30
#            1       0.91      0.64      0.75        50
#
#     accuracy                           0.74        80
#    macro avg       0.76      0.77      0.74        80
# weighted avg       0.80      0.74      0.74        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 15 features are:
# ['su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'pot', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.921875 0.84375  0.890625 0.9375   0.890625]
# Accuracy with k fold validation 89.69
# Accuracy list [74.69, 80.62, 80.94, 89.05999999999999, 88.12, 89.69]
#
# Confusion matrix:
#  [[30  0]
#  [ 8 42]]
#
#
# Precision :
#  89.47
# Precision list [31.25, 31.25, 31.25, 90.53999999999999, 88.46000000000001, 89.47]
#
# F1-score:
#  89.77000000000001
# F1-score list [38.46, 38.46, 38.46, 91.01, 88.53, 89.77000000000001]
#
# Recall:
#  92.0
# Recall list [50.0, 50.0, 50.0, 93.0, 91.0, 92.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        30
#            1       1.00      0.84      0.91        50
#
#     accuracy                           0.90        80
#    macro avg       0.89      0.92      0.90        80
# weighted avg       0.92      0.90      0.90        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 15 features are:
# ['su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'pot', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81, 67.81, 67.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [23 27]]
#
#
# Precision :
#  74.0
# Precision list [74.0, 73.35000000000001, 73.35000000000001, 73.35000000000001, 73.35000000000001, 74.0]
#
# F1-score:
#  68.75
# F1-score list [68.75, 67.47999999999999, 67.47999999999999, 67.47999999999999, 67.47999999999999, 68.75]
#
# Recall:
#  73.67
# Recall list [73.67, 72.67, 72.67, 72.67, 72.67, 73.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69        30
#            1       0.93      0.54      0.68        50
#
#     accuracy                           0.69        80
#    macro avg       0.74      0.74      0.69        80
# weighted avg       0.79      0.69      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# ## No of features used:18

# %%
numberOfFeatureForClassifier(18)
# Out:
# Using Random Forest Classification....
#
# Using Random Forest Classification
# The top 18 features are:
# ['bp', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'pot', 'hemo', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.984375 0.953125 0.953125 0.953125 1.      ]
# Accuracy with k fold validation 96.88
# Accuracy list [84.06, 84.69, 85.31, 90.31, 88.12, 93.75, 96.88] & No of Feature list ['4', '5', '6', '7', '9', '15', '18']
#
# Confusion matrix:
#  [[30  0]
#  [ 0 50]]
#
#
# Precision :
#  100.0
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 85.14, 86.46000000000001, 94.12, 100.0]
#
# F1-score:
#  100.0
# F1-score list [77.98, 83.16, 83.16, 85.6, 86.83, 94.78999999999999, 100.0]
#
# Recall:
#  100.0
# Recall list [79.0, 84.33, 84.33, 86.33, 87.33, 96.0, 100.0]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
#
# ---------------------------------------------------------------------
#
#
# Using Decision Tree Classification....
#
# Using Decision Tree Classification
# The top 18 features are:
# ['bp', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'pot', 'hemo', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.953125 0.921875 0.890625 0.953125 0.9375  ]
# Accuracy with k fold validation 93.12
# Accuracy list [84.69, 85.61999999999999, 87.19, 90.94, 88.75, 87.5, 93.12]
#
# Confusion matrix:
#  [[30  0]
#  [ 2 48]]
#
#
# Precision :
#  96.88
# Precision list [77.62, 82.69999999999999, 82.69999999999999, 83.89, 83.89, 90.32, 96.88]
#
# F1-score:
#  97.37
# F1-score list [77.98, 83.16, 83.16, 84.38, 84.38, 90.93, 97.37]
#
# Recall:
#  98.0
# Recall list [79.0, 84.33, 84.33, 85.33, 85.33, 92.33, 98.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        30
#            1       1.00      0.96      0.98        50
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80
#
# ---------------------------------------------------------------------
#
#
# Using KNN Classification....
#
# Using KNN Classification
# The top 18 features are:
# ['bp', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'pot', 'hemo', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.6875   0.703125 0.6875   0.78125  0.71875 ]
# Accuracy with k fold validation 71.56
# Accuracy list [65.94, 65.31, 65.94, 67.5, 67.19000000000001, 71.88, 71.56]
#
# Confusion matrix:
#  [[27  3]
#  [18 32]]
#
#
# Precision :
#  75.71
# Precision list [75.71, 76.03999999999999, 76.03999999999999, 76.03999999999999, 76.03999999999999, 75.71, 75.71]
#
# F1-score:
#  73.65
# F1-score list [73.65, 72.48, 72.48, 72.48, 72.48, 73.65, 73.65]
#
# Recall:
#  77.0
# Recall list [77.0, 76.67, 76.67, 76.67, 76.67, 77.0, 77.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.90      0.72        30
#            1       0.91      0.64      0.75        50
#
#     accuracy                           0.74        80
#    macro avg       0.76      0.77      0.74        80
# weighted avg       0.80      0.74      0.74        80
#
# ---------------------------------------------------------------------
#
#
# Using Logistic Regression Classification....
#
# Using Logistic Regression Classification
# The top 18 features are:
# ['bp', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'pot', 'hemo', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.90625  0.9375   0.953125 0.890625 0.96875 ]
# Accuracy with k fold validation 93.12
# Accuracy list [74.69, 80.62, 80.94, 89.05999999999999, 88.12, 89.69, 93.12]
#
# Confusion matrix:
#  [[30  0]
#  [ 1 49]]
#
#
# Precision :
#  98.39
# Precision list [31.25, 31.25, 31.25, 90.53999999999999, 88.46000000000001, 89.47, 98.39]
#
# F1-score:
#  98.68
# F1-score list [38.46, 38.46, 38.46, 91.01, 88.53, 89.77000000000001, 98.68]
#
# Recall:
#  99.0
# Recall list [50.0, 50.0, 50.0, 93.0, 91.0, 92.0, 99.0]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.98      0.99        50
#
#     accuracy                           0.99        80
#    macro avg       0.98      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80
#
# ---------------------------------------------------------------------
#
#
# Using SVM Classification....
#
# Using Support vector machine Classification
# The top 18 features are:
# ['bp', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'pot', 'hemo', 'wbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']
#
# Accuracy of 5 fold - [0.578125 0.6875   0.65625  0.765625 0.703125]
# Accuracy with k fold validation 67.81
# Accuracy list [67.81, 67.81, 67.81, 67.81, 67.81, 67.81, 67.81]
#
# Confusion matrix:
#  [[28  2]
#  [23 27]]
#
#
# Precision :
#  74.0
# Precision list [74.0, 73.35000000000001, 73.35000000000001, 73.35000000000001, 73.35000000000001, 74.0, 74.0]
#
# F1-score:
#  68.75
# F1-score list [68.75, 67.47999999999999, 67.47999999999999, 67.47999999999999, 67.47999999999999, 68.75, 68.75]
#
# Recall:
#  73.67
# Recall list [73.67, 72.67, 72.67, 72.67, 72.67, 73.67, 73.67]
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69        30
#            1       0.93      0.54      0.68        50
#
#     accuracy                           0.69        80
#    macro avg       0.74      0.74      0.69        80
# weighted avg       0.79      0.69      0.69        80
#
# ---------------------------------------------------------------------

# %% [markdown]
# # MODEL EVALUATION

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[0],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[0],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[0],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[0],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[0],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
accuracy_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
accuracy_matrix
# Out:
#   features     rf     dt     lr    knn    svm
# 0        4  84.06  84.69  74.69  65.94  67.81
# 1        5  84.69  85.62  80.62  65.31  67.81
# 2        6  85.31  87.19  80.94  65.94  67.81
# 3        7  90.31  90.94  89.06  67.50  67.81
# 4        9  88.12  88.75  88.12  67.19  67.81
# 5       15  93.75  87.50  89.69  71.88  67.81
# 6       18  96.88  93.12  93.12  71.56  67.81

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
accuracy_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Accuracy')

plt.xlabel('Features')
plt.ylabel('Accuracy')

# show the plot
plt.show()

# %% [markdown]
# ## Precision

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[1],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[1],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[1],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[1],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[1],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
precision_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
precision_matrix
# Out:
#   features      rf     dt     lr    knn    svm
# 0        4   77.62  77.62  31.25  75.71  74.00
# 1        5   82.70  82.70  31.25  76.04  73.35
# 2        6   82.70  82.70  31.25  76.04  73.35
# 3        7   85.14  83.89  90.54  76.04  73.35
# 4        9   86.46  83.89  88.46  76.04  73.35
# 5       15   94.12  90.32  89.47  75.71  74.00
# 6       18  100.00  96.88  98.39  75.71  74.00

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
precision_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
precision_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
precision_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
precision_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
precision_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Precision')

plt.xlabel('Features')
plt.ylabel('Precision')

# show the plot
plt.show()

# %% [markdown]
# ## F1

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[2],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[2],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[2],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[2],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[2],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
F1_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
F1_matrix
# Out:
#   features      rf     dt     lr    knn    svm
# 0        4   77.98  77.98  38.46  73.65  68.75
# 1        5   83.16  83.16  38.46  72.48  67.48
# 2        6   83.16  83.16  38.46  72.48  67.48
# 3        7   85.60  84.38  91.01  72.48  67.48
# 4        9   86.83  84.38  88.53  72.48  67.48
# 5       15   94.79  90.93  89.77  73.65  68.75
# 6       18  100.00  97.37  98.68  73.65  68.75

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
F1_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
F1_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
F1_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
F1_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
F1_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and F1-score')

plt.xlabel('Features')
plt.ylabel('F1-score')

# show the plot
plt.show()

# %% [markdown]
# ## Recall

# %%
# A dictionary which represents data
data_dict = { 'features': n_Featurelist,               #['4','5','6','7','9','15','18'],
              'rf': rf_list[3],                        #[93.40,96.60,98.40,97.80,99.10,98.80,98.40],
              'dt': dt_list[3],                        #[93.10,96.20,97.20,96.90,97.50,95.60,95.60],
              'lr': lr_list[3],                        #[91.60,91.10,94.70,96.20,96.20,96.20,95.00],
              'knn' :knn_list[3],                       #[93.40,92.80,96.20,93.40,93.80,72.80,72.80],
              'svm' :svm_list[3],                      #[92.20,92.80,95.00,93.40,93.80,67.80,67.80]
              }
  
# creating a data frame object
recall_matrix = pd.DataFrame(data_dict)
  
# show the dataframe
recall_matrix
# Out:
#   features      rf     dt    lr    knn    svm
# 0        4   79.00  79.00  50.0  77.00  73.67
# 1        5   84.33  84.33  50.0  76.67  72.67
# 2        6   84.33  84.33  50.0  76.67  72.67
# 3        7   86.33  85.33  93.0  76.67  72.67
# 4        9   87.33  85.33  91.0  76.67  72.67
# 5       15   96.00  92.33  92.0  77.00  73.67
# 6       18  100.00  98.00  99.0  77.00  73.67

# %%
#Get current axis
ax = plt.gca()

# line plot for Random Forest
recall_matrix.plot(kind = 'line',x = 'features',y = 'rf',label = "Random Forest",linestyle='dotted',color = 'green',ax = ax)

# line plot for Decision Tree
recall_matrix.plot(kind = 'line',x = 'features',y = 'dt',label = "Decision Tree",linestyle='dashed',color = 'blue',ax = ax)

# line plot for KNN
recall_matrix.plot(kind = 'line',x = 'features',y = 'knn',label = "KNN",linestyle='dashdot',color = 'black',ax = ax)

# line plot for Logistic Regression
recall_matrix.plot(kind = 'line',x = 'features',y = 'lr',label = "Logistic Regression",linestyle='dashed',linewidth='4',color = 'red',ax = ax)

# line plot for SVM
recall_matrix.plot(kind = 'line',x = 'features',y = 'svm',label = "Support Vector Machine",linestyle='solid',color = 'orange',ax = ax)

# set the title
plt.title('Relationship Between No. of Features and Recall')

plt.xlabel('Features')
plt.ylabel('Recall')

# show the plot
plt.show()
